# %%
import pandas as pd
import json

# %%
covid = "data.csv"
covid_df = pd.read_csv(covid)
covid_df.head()
# Out:
#   city county state country  cases  deaths  recovered  tested  active  \
# 0  NaN    NaN   NaN     AFG   84.0     2.0        NaN     NaN     NaN
# 1  NaN    NaN   NaN     ALB  146.0     5.0        NaN     NaN     NaN
# 2  NaN    NaN   NaN     DZA  302.0    21.0        NaN     NaN     NaN
# 3  NaN    NaN   NaN     AND  188.0     1.0        NaN     NaN     NaN
# 4  NaN    NaN   NaN     AGO    3.0     0.0        NaN     NaN     NaN
#
#    population        lat       long  \
# 0  34124811.0  33.930139  67.689542
# 1   3047987.0  41.112453  20.154356
# 2  40969443.0  28.032339   1.643238
# 3     85702.0  42.515016   1.568152
# 4  29310273.0 -11.211304  17.898856
#
#                                           url  \
# 0  https://github.com/CSSEGISandData/COVID-19
# 1  https://github.com/CSSEGISandData/COVID-19
# 2  https://github.com/CSSEGISandData/COVID-19
# 3  https://github.com/CSSEGISandData/COVID-19
# 4  https://github.com/CSSEGISandData/COVID-19
#
#                                          maintainers aggregate    rating  \
# 0  [{"name":"Larry Davis","email":"lazdnet@gmail....   country  0.470588
# 1  [{"name":"Larry Davis","email":"lazdnet@gmail....   country  0.470588
# 2  [{"name":"Larry Davis","email":"lazdnet@gmail....   country  0.470588
# 3  [{"name":"Larry Davis","email":"lazdnet@gmail....   country  0.470588
# 4  [{"name":"Larry Davis","email":"lazdnet@gmail....   country  0.470588
#
#                    tz  featureId sources curators
# 0      ["Asia/Kabul"]        0.0     NaN      NaN
# 1   ["Europe/Tirane"]        1.0     NaN      NaN
# 2  ["Africa/Algiers"]        2.0     NaN      NaN
# 3  ["Europe/Andorra"]        3.0     NaN      NaN
# 4   ["Africa/Luanda"]        4.0     NaN      NaN

# %%
del covid_df['city']
covid_df
# Out:
#                county state country  cases  deaths  recovered  tested  active  \
# 0                 NaN   NaN     AFG   84.0     2.0        NaN     NaN     NaN
# 1                 NaN   NaN     ALB  146.0     5.0        NaN     NaN     NaN
# 2                 NaN   NaN     DZA  302.0    21.0        NaN     NaN     NaN
# 3                 NaN   NaN     AND  188.0     1.0        NaN     NaN     NaN
# 4                 NaN   NaN     AGO    3.0     0.0        NaN     NaN     NaN
# ...               ...   ...     ...    ...     ...        ...     ...     ...
# 3628     Teton County    WY     USA    6.0     NaN        NaN     NaN     NaN
# 3629     Uinta County    WY     USA    0.0     NaN        NaN     NaN     NaN
# 3630  Washakie County    WY     USA    0.0     NaN        NaN     NaN     NaN
# 3631    Weston County    WY     USA    0.0     NaN        NaN     NaN     NaN
# 3632              NaN    WY     USA   49.0     NaN        NaN     NaN     NaN
#
#       population        lat        long  \
# 0     34124811.0  33.930139   67.689542
# 1      3047987.0  41.112453   20.154356
# 2     40969443.0  28.032339    1.643238
# 3        85702.0  42.515016    1.568152
# 4     29310273.0 -11.211304   17.898856
# ...          ...        ...         ...
# 3628     23081.0  43.950812 -110.553385
# 3629     20299.0  41.287295 -110.547361
# 3630      7885.0  43.834371 -107.830746
# 3631      6967.0  43.840034 -104.567947
# 3632    578759.0  42.999967 -107.551996
#
#                                                     url  \
# 0            https://github.com/CSSEGISandData/COVID-19
# 1            https://github.com/CSSEGISandData/COVID-19
# 2            https://github.com/CSSEGISandData/COVID-19
# 3            https://github.com/CSSEGISandData/COVID-19
# 4            https://github.com/CSSEGISandData/COVID-19
# ...                                                 ...
# 3628  https://health.wyo.gov/publichealth/infectious...
# 3629  https://health.wyo.gov/publichealth/infectious...
# 3630  https://health.wyo.gov/publichealth/infectious...
# 3631  https://health.wyo.gov/publichealth/infectious...
# 3632  https://health.wyo.gov/publichealth/infectious...
#
#                                             maintainers aggregate    rating  \
# 0     [{"name":"Larry Davis","email":"lazdnet@gmail....   country  0.470588
# 1     [{"name":"Larry Davis","email":"lazdnet@gmail....   country  0.470588
# 2     [{"name":"Larry Davis","email":"lazdnet@gmail....   country  0.470588
# 3     [{"name":"Larry Davis","email":"lazdnet@gmail....   country  0.470588
# 4     [{"name":"Larry Davis","email":"lazdnet@gmail....   country  0.470588
# ...                                                 ...       ...       ...
# 3628  [{"name":"Larry Davis","email":"lazdnet@gmail....    county  0.254902
# 3629  [{"name":"Larry Davis","email":"lazdnet@gmail....    county  0.254902
# 3630  [{"name":"Larry Davis","email":"lazdnet@gmail....    county  0.254902
# 3631  [{"name":"Larry Davis","email":"lazdnet@gmail....    county  0.254902
# 3632  [{"name":"Larry Davis","email":"lazdnet@gmail....    county  0.176471
#
#                       tz  featureId sources curators
# 0         ["Asia/Kabul"]        0.0     NaN      NaN
# 1      ["Europe/Tirane"]        1.0     NaN      NaN
# 2     ["Africa/Algiers"]        2.0     NaN      NaN
# 3     ["Europe/Andorra"]        3.0     NaN      NaN
# 4      ["Africa/Luanda"]        4.0     NaN      NaN
# ...                  ...        ...     ...      ...
# 3628  ["America/Denver"]     3576.0     NaN      NaN
# 3629  ["America/Denver"]     3577.0     NaN      NaN
# 3630  ["America/Denver"]     3578.0     NaN      NaN
# 3631  ["America/Denver"]     3579.0     NaN      NaN
# 3632  ["America/Denver"]     3580.0     NaN      NaN
#
# [3633 rows x 19 columns]

# %%
covid_df.count()
# Out:
# county         3205
# state          3458
# country        3633
# cases          3629
# deaths         1511
# recovered       446
# tested          439
# active          421
# population     3465
# lat            3590
# long           3590
# url            3633
# maintainers    1045
# aggregate      3558
# rating         3633
# tz             3584
# featureId      3584
# sources         440
# curators        103
# dtype: int64

# %%
columns = ["county", "state", "country", "cases", "deaths", "lat", "long"]
covid_usa = covid_df.loc[covid_df["country"] == "USA", columns]
covid_usa
# Out:
#                county state country  cases  deaths        lat        long
# 348               NaN    ND     USA   39.0     0.0  47.467211 -100.301958
# 349               NaN    NV     USA  321.0     6.0  38.501823 -117.020477
# 350               NaN    VT     USA  123.0     8.0  43.871504  -72.472196
# 351               NaN    PR     USA   51.0     2.0        NaN         NaN
# 352               NaN    AS     USA    0.0     0.0        NaN         NaN
# ...               ...   ...     ...    ...     ...        ...         ...
# 3628     Teton County    WY     USA    6.0     NaN  43.950812 -110.553385
# 3629     Uinta County    WY     USA    0.0     NaN  41.287295 -110.547361
# 3630  Washakie County    WY     USA    0.0     NaN  43.834371 -107.830746
# 3631    Weston County    WY     USA    0.0     NaN  43.840034 -104.567947
# 3632              NaN    WY     USA   49.0     NaN  42.999967 -107.551996
#
# [3102 rows x 7 columns]

# %%
# usa_index = covid_usa.reset_index(drop=True)
cleanup = covid_usa.dropna(subset=['state'])

# %%
cleanup = cleanup.dropna(subset=['lat'])

# %%
cleanup = cleanup.dropna(subset=['long'])

# %%
cleanup = cleanup[cleanup['cases'] != 0]

# %%
cleanup.count()
# Out:
# county     1465
# state      1518
# country    1518
# cases      1518
# deaths      726
# lat        1518
# long       1518
# dtype: int64

# %%
covid_us =cleanup

# %%
covid_us.dtypes
# Out:
# county      object
# state       object
# country     object
# cases      float64
# deaths     float64
# lat        float64
# long       float64
# dtype: object

# %%
covid_us = covid_us.reset_index(drop=True)

# %%
covid_us
# Out:
#                           county state country  cases  deaths        lat  \
# 0                            NaN    ND     USA   39.0     0.0  47.467211
# 1                            NaN    NV     USA  321.0     6.0  38.501823
# 2                            NaN    VT     USA  123.0     8.0  43.871504
# 3     Gulf Coast Economic Region    AK     USA    5.0     NaN  59.491968
# 4       Interior Economic Region    AK     USA   11.0     NaN  65.204163
# ...                          ...   ...     ...    ...     ...        ...
# 1513                 Park County    WY     USA    1.0     NaN  44.409599
# 1514             Sheridan County    WY     USA    4.0     NaN  44.779128
# 1515           Sweetwater County    WY     USA    1.0     NaN  41.634037
# 1516                Teton County    WY     USA    6.0     NaN  43.950812
# 1517                         NaN    WY     USA   49.0     NaN  42.999967
#
#             long
# 0    -100.301958
# 1    -117.020477
# 2     -72.472196
# 3    -148.903015
# 4    -151.024977
# ...          ...
# 1513 -109.803725
# 1514 -106.960709
# 1515 -108.779115
# 1516 -110.553385
# 1517 -107.551996
#
# [1518 rows x 7 columns]

# %%
covid_us.to_json(r'covid_usa.json', orient = 'records')
